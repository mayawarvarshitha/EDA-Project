# %% [markdown]
# # EXPLORATORY DATA ANALYSIS ( EDA )

# %%
#Importing Required Libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#Reading the Dataset
df = pd.read_csv('supermarket_sales.csv', parse_dates=['Date'])

# %%
import warnings

# %%
warnings.filterwarnings('ignore')

# %% [markdown]
# # Attribute information
#
# #Invoice id: Computer generated sales slip invoice identification number
#
# #Branch: Branch of supercenter
# #(3 branches are available identified by A, B and C).
#
# #City: Location of supercenters
#
# #Customer type: Type of customers, recorded by Members for customers using member card and Normal for without member card.
#
# #Gender: Gender type of customer
#
# #Product line: General item categorization groups - Electronic accessories, Fashion accessories,
# #Food and beverages, Health and beauty, Home and lifestyle, Sports and travel
#
# #Unit price: Price of each product in $
#
# #Quantity: Number of products purchased by customer
#
# #Tax: 5% tax fee for customer buying
#
# #Total: Total price including tax
#
# #Date: Date of purchase (Record available from January 2019 to March 2019)
#
# #Time: Purchase time (10am to 9pm)
#
# #Payment: Payment used by customer for purchase (3 methods are available – Cash, Credit card and Ewallet)
#
# #COGS: Cost of goods sold
#
# #Gross margin percentage: Gross margin percentage
#
# #Gross income: Gross income
#
# #Rating: Customer stratification rating on their overall shopping experience (On a scale of 1 to 10)

# %% [markdown]
# ## 1.Display Top 5 Rows of The Datase

# %%
df.head(5) #or df.head(4)
# Out:
#     Invoice ID Branch       City Customer type  Gender  \
# 0  750-67-8428      A     Yangon        Member  Female
# 1  226-31-3081      C  Naypyitaw        Normal  Female
# 2  631-41-3108      A     Yangon        Normal    Male
# 3  123-19-1176      A     Yangon        Member    Male
# 4  373-73-7910      A     Yangon        Normal    Male
#
#              Product line  Unit price  Quantity   Tax 5%     Total       Date  \
# 0       Health and beauty       74.69         7  26.1415  548.9715 2019-01-05
# 1  Electronic accessories       15.28         5   3.8200   80.2200 2019-03-08
# 2      Home and lifestyle       46.33         7  16.2155  340.5255 2019-03-03
# 3       Health and beauty       58.22         8  23.2880  489.0480 2019-01-27
# 4       Sports and travel       86.31         7  30.2085  634.3785 2019-02-08
#
#     Time      Payment    cogs  gross margin percentage  gross income  Rating  \
# 0  13:08      Ewallet  522.83                 4.761905       26.1415     9.1
# ...

# %% [markdown]
# ## 2.Display Last 5 Rows From The Dataset

# %%
df.tail(5)
# Out:
#       Invoice ID Branch       City Customer type  Gender         Product line  \
# 995  233-67-5758      C  Naypyitaw        Normal    Male    Health and beauty
# 996  303-96-2227      B   Mandalay        Normal  Female   Home and lifestyle
# 997  727-02-1313      A     Yangon        Member    Male   Food and beverages
# 998  347-56-2442      A     Yangon        Normal    Male   Home and lifestyle
# 999  849-09-3807      A     Yangon        Member  Female  Fashion accessories
#
#      Unit price  Quantity   Tax 5%      Total       Date   Time  Payment  \
# 995       40.35         1   2.0175    42.3675 2019-01-29  13:46  Ewallet
# 996       97.38        10  48.6900  1022.4900 2019-03-02  17:16  Ewallet
# 997       31.84         1   1.5920    33.4320 2019-02-09  13:22     Cash
# 998       65.82         1   3.2910    69.1110 2019-02-22  15:33     Cash
# 999       88.34         7  30.9190   649.2990 2019-02-18  13:28     Cash
#
# ...

# %% [markdown]
# ## 3.Print Random 5 Rows From Our Dataset

# %%
df.sample(5)
# Out:
#       Invoice ID Branch       City Customer type  Gender  \
# 71   796-12-2025      C  Naypyitaw        Normal    Male
# 125  668-90-8900      A     Yangon        Normal  Female
# 829  416-17-9926      A     Yangon        Member  Female
# 997  727-02-1313      A     Yangon        Member    Male
# 64   853-23-2453      B   Mandalay        Member    Male
#
#                Product line  Unit price  Quantity   Tax 5%     Total  \
# 71      Fashion accessories       62.12        10  31.0600  652.2600
# 125      Home and lifestyle       93.69         7  32.7915  688.6215
# 829  Electronic accessories       74.22        10  37.1100  779.3100
# 997      Food and beverages       31.84         1   1.5920   33.4320
# 64        Health and beauty       75.74         4  15.1480  318.1080
#
#           Date   Time      Payment    cogs  gross margin percentage  \
# 71  2019-02-11  16:19         Cash  621.20                 4.761905
# ...

# %% [markdown]
# ## 4. Find Shape of Our Dataset

# %%
 df.shape
# Out:
# (1000, 17)

# %%
print('Number of Columns:', df.shape[0])
print('Number of Rows:', df.shape[1])
# Out:
# Number of Columns: 1000
# Number of Rows: 17

# %% [markdown]
# ## 5. Check For NULL Values in The Dataset

# %%
df.isnull().sum()
#we do not have any null values
# Out:
# Invoice ID                 0
# Branch                     0
# City                       0
# Customer type              0
# Gender                     0
# Product line               0
# Unit price                 0
# Quantity                   0
# Tax 5%                     0
# Total                      0
# Date                       0
# Time                       0
# Payment                    0
# cogs                       0
# gross margin percentage    0
# gross income               0
# Rating                     0
# dtype: int64

# %% [markdown]
# ## 6. Get Infrimation About Our Dataset

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 17 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Invoice ID               1000 non-null   object
#  1   Branch                   1000 non-null   object
#  2   City                     1000 non-null   object
#  3   Customer type            1000 non-null   object
#  4   Gender                   1000 non-null   object
#  5   Product line             1000 non-null   object
#  6   Unit price               1000 non-null   float64
#  7   Quantity                 1000 non-null   int64
#  8   Tax 5%                   1000 non-null   float64
#  9   Total                    1000 non-null   float64
#  10  Date                     1000 non-null   datetime64[ns]
#  11  Time                     1000 non-null   object
#  12  Payment                  1000 non-null   object
# ...

# %% [markdown]
# ## 7. Get Overall Statistics About The Dataset

# %%
df.describe()
# Out:
#         Unit price     Quantity       Tax 5%        Total  \
# count  1000.000000  1000.000000  1000.000000  1000.000000
# mean     55.672130     5.510000    15.379369   322.966749
# min      10.080000     1.000000     0.508500    10.678500
# 25%      32.875000     3.000000     5.924875   124.422375
# 50%      55.230000     5.000000    12.088000   253.848000
# 75%      77.935000     8.000000    22.445250   471.350250
# max      99.960000    10.000000    49.650000  1042.650000
# std      26.494628     2.923431    11.708825   245.885335
#
#                              Date        cogs  gross margin percentage  \
# count                        1000  1000.00000              1000.000000
# mean   2019-02-14 00:05:45.600000   307.58738                 4.761905
# min           2019-01-01 00:00:00    10.17000                 4.761905
# 25%           2019-01-24 00:00:00   118.49750                 4.761905
# 50%           2019-02-13 00:00:00   241.76000                 4.761905
# ...

# %%
#Saparating Catogorical columns and Numerical Columns
cat = []
num = []

for column in df.columns:
    if df[column].nunique() > 10:
        num.append(column)
    else:
        cat.append(column)

# %%
cat
# Out:
# ['Branch',
#  'City',
#  'Customer type',
#  'Gender',
#  'Product line',
#  'Quantity',
#  'Payment',
#  'gross margin percentage']

# %%
num
# Out:
# ['Invoice ID',
#  'Unit price',
#  'Tax 5%',
#  'Total',
#  'Date',
#  'Time',
#  'cogs',
#  'gross income',
#  'Rating']

# %% [markdown]
# # UNIVARIATE ANALYSIS

# %% [markdown]
# ## 1. Find Aggregate Sales Among Branches. (Categorical Columns)

# %%
sns.countplot(x='Branch', data = df)
plt.title('Count of each branch')
plt.show()

# %%
df['Branch'].value_counts().plot(kind='pie', autopct='%1.2f%%')
# Out:
# <Axes: ylabel='count'>

# %% [markdown]
# ## 2. Find The Most Popular Payment Method Used BY Customers ( Categoriccal Columns)

# %%
colors = ['blue','green','orange']
df['Payment'].value_counts().plot(kind='bar', color=colors)
plt.title('Count of Each Payment Method')
plt.show()

# %% [markdown]
# ## 3. Find The Distrubution of Customer Ratings. (Numerical Column)

# %%
sns.distplot(df['Rating'])
# Out:
# <Axes: xlabel='Rating', ylabel='Density'>

# %%
df['Rating'].skew()
# Out:
# 0.00900964876573073

# %% [markdown]
# ## 4. Find the Distribution of Cost of Goods Sold ( Numerical Column)

# %%
sns.distplot(df['cogs'])
# Out:
# <Axes: xlabel='cogs', ylabel='Density'>

# %%
sns.boxplot(df['cogs'])
plt.title(' Distribution of Cost of Goods Sold ')
# Out:
# Text(0.5, 1.0, ' Distribution of Cost of Goods Sold ')

# %%
df['cogs'].skew() #The skew of cogs is right skewed and it shows positvly skewed
# Out:
# 0.8925698049581418

# %% [markdown]
# # BIVARIATE ANALYSIS / MULTIVARIATE ANALYSIS

# %% [markdown]
# ## 1. Does The Cost of Goods Sold After The Rating That The Customers Provide?

# %%
sns.scatterplot(x='cogs',y='Rating',data=df)
# Out:
# <Axes: xlabel='cogs', ylabel='Rating'>

# %%
#As here we can see that there is no relation between cogs and Rating

# %% [markdown]
# ## 2. Does Gross Income Affect The Ratings That Customers Provide?

# %%
sns.scatterplot(x='gross income',y='Rating',data=df)
# Out:
# <Axes: xlabel='gross income', ylabel='Rating'>

# %%
#As here we can see that there is no relation between gross income and Rating

# %% [markdown]
# ## 3. Find The Most Profitable Branch As Per Gross Income. ( Numerical - Categorical )

# %%
#BIVARIATE ANALYSIS
sns.barplot(x='Branch',y='gross income',data = df)
# Out:
# <Axes: xlabel='Branch', ylabel='gross income'>

# %%
#MULTIVARIATE ANALYSIS
sns.barplot(x='Branch',y='gross income',data = df,hue=df['City'])
# Out:
# <Axes: xlabel='Branch', ylabel='gross income'>

# %%
#As we can see that Branch C has slightly Have higher income while comparing to A and B.
Branch_counts = df.groupby('Branch')['gross income'].sum()
Branch_counts
# Out:
# Branch
# A    5057.1605
# B    5057.0320
# C    5265.1765
# Name: gross income, dtype: float64

# %% [markdown]
# ## 4. Is There Any Relationship Between Gender And Gross Income? ( Numerical - Categorical)

# %%
sns.boxplot(x='Gender',y='gross income',data=df)
# Out:
# <Axes: xlabel='Gender', ylabel='gross income'>

# %%
sns.boxplot(x='Gender',y='gross income',data=df,hue=df['Customer type'])
# Out:
# <Axes: xlabel='Gender', ylabel='gross income'>

# %%
'''Here we can see in boxplot female customers are slight higher then compared to male customers, 
and also we have added customer type where its showing Member and Normal, 
which are Member contributing more in gross income while comparing to Normal tpye.'''

# %% [markdown]
# ## 5. Find The Product Line That Generates The Most Income. (Numerical - Categorical)

# %%
sns.barplot(x='Product line',y='gross income',data=df)
plt.xticks(rotation=60)
plt.show()

# %%
"""So, In barplot we can see that first Home and Lifestyle Proudct line generates the most income, 
The Second Product line in Sports and Travel genretes the Second Income."""
# Out:
# 'So, In barplot we can see that first Home and Lifestyle Proudct line generates the most income, \nThe Second Product line in Sports and Travel genretes the Second Income.'

# %% [markdown]
# ## 6. Find The Highest Unit Price In The Product Line. (Numerical - Categorical)

# %%
sns.barplot(x='Product line',y='Unit price',data=df)
plt.xticks(rotation=60)
plt.show()

# %%
'''Sports and Travel The Highest Unit Price In The Product Line'''

# %% [markdown]
# ## 7. Find Different Payment Methods Used By Customers Citywise.

# %%
# Creating a crosstab
crosstab_data = pd.crosstab(df['City'], df['Payment'])

# Creating a heatmap
plt.figure(figsize=(10, 6))
sns.heatmap(crosstab_data, annot=True, fmt='d', cmap='Blues')

plt.xlabel('Payment')
plt.ylabel('City')
plt.title('Crosstab Heatmap of Payment by City')
plt.show()

# %% [markdown]
# ## 8. Which Product Line Is Purchased In The Highest Quantity?

# %%
sns.barplot(x='Product line',y='Quantity',data=df)
plt.xticks(rotation=60)
plt.show()

# %%
# Electroic Accessories Is Purchased In The Highest Quantity

# %% [markdown]
# ## 9. Display Daily Sales by Day of the Week

# %%
dw_mapping= {
    0:'Mon',
    1:'Tue',
    2:'Wed',
    3:'Thur',
    4:'Fri',
    5:'Sat',
    6:'Sun'
}

# %%
df['day_of_week'] =df['Date'].dt.dayofweek.map(dw_mapping)
df.head()
# Out:
#     Invoice ID Branch       City Customer type  Gender  \
# 0  750-67-8428      A     Yangon        Member  Female
# 1  226-31-3081      C  Naypyitaw        Normal  Female
# 2  631-41-3108      A     Yangon        Normal    Male
# 3  123-19-1176      A     Yangon        Member    Male
# 4  373-73-7910      A     Yangon        Normal    Male
#
#              Product line  Unit price  Quantity   Tax 5%     Total       Date  \
# 0       Health and beauty       74.69         7  26.1415  548.9715 2019-01-05
# 1  Electronic accessories       15.28         5   3.8200   80.2200 2019-03-08
# 2      Home and lifestyle       46.33         7  16.2155  340.5255 2019-03-03
# 3       Health and beauty       58.22         8  23.2880  489.0480 2019-01-27
# 4       Sports and travel       86.31         7  30.2085  634.3785 2019-02-08
#
#     Time      Payment    cogs  gross margin percentage  gross income  Rating  \
# 0  13:08      Ewallet  522.83                 4.761905       26.1415     9.1
# ...

# %%
df['day_of_week'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='day_of_week'>

# %%
'''From this bar plot we can see that Sales is higher in Saturday because its weekeng
, by this i can Manage my Staffing and Shift timing
Suprisingly Sales are high on Tuesday,
Sales are Lowest on Monday by this i can Keep Offers in lowest Sales Days to Get Better Sales'''

# %% [markdown]
# ## 10. What Will Be The Highest Months for Sales

# %%
month_mapping = {
    1:'Jan',
    2:'Feb',
    3:'March'
    
}

# %%
df['month'] =df['Date'].dt.month.map(month_mapping)
df.head()
# Out:
#     Invoice ID Branch       City Customer type  Gender  \
# 0  750-67-8428      A     Yangon        Member  Female
# 1  226-31-3081      C  Naypyitaw        Normal  Female
# 2  631-41-3108      A     Yangon        Normal    Male
# 3  123-19-1176      A     Yangon        Member    Male
# 4  373-73-7910      A     Yangon        Normal    Male
#
#              Product line  Unit price  Quantity   Tax 5%     Total       Date  \
# 0       Health and beauty       74.69         7  26.1415  548.9715 2019-01-05
# 1  Electronic accessories       15.28         5   3.8200   80.2200 2019-03-08
# 2      Home and lifestyle       46.33         7  16.2155  340.5255 2019-03-03
# 3       Health and beauty       58.22         8  23.2880  489.0480 2019-01-27
# 4       Sports and travel       86.31         7  30.2085  634.3785 2019-02-08
#
#     Time      Payment    cogs  gross margin percentage  gross income  Rating  \
# 0  13:08      Ewallet  522.83                 4.761905       26.1415     9.1
# ...

# %%
df['month'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='month'>

# %%
#Sales are High in January.

# %% [markdown]
# # THANK YOU BY SAI TEJA M
